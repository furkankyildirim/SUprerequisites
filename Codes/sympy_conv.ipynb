# %% [markdown]
# We would like to use SymPy methods to analyze course prerequisites. For this, every course will be defined as a variable (Symbol) and the prerequisite strings will be converted into SymPy expressions.

# %%
from sympy import *
from sympy.logic.boolalg import BooleanFunction

import json
import re
import time

chrono1 = time.perf_counter()

def parse_course_name(full_name):
    return "".join(full_name.split(" - ")[0].split(" "))

with open("CoursePrerequisites.json", "r") as f:
    courses = json.loads(f.read())
    
# https://stackoverflow.com/a/25244576
def strike(text):
    result = ''
    for c in text:
        result = result + c + '\u0336'
    return result

# %%
fullnames_dict = {} # full course name -> course name
courses_dict = {} # course name -> course symbol
prereq_strings_dict = {} # course name -> prereq string

for (course_name, prerequisites) in courses.items():
    name = parse_course_name(course_name)
    fullnames_dict[course_name] = name
    courses_dict[name] = Symbol(name)
    prereq_strings_dict[name] = prerequisites

# %%
# prereqs_dict: course name -> prerequisite expression or none
prereqs_dict = {}
# "CS515" -> 𝐴𝐶𝐶201∨𝑀𝐺𝑀𝑇202

for (name, prerequisites_string) in prereq_strings_dict.items():
    if not prerequisites_string:
        continue
    else:
        try:
            prereqs_dict[name] = eval(prerequisites_string, courses_dict)
        except NameError:
            # there are some required classes that are not in the symbols dictionary yet (were not in the catalog)
            # TODO: these should be marked in some way
            
            # find all course names
            for new_course_name in re.findall("\w+", prerequisites_string):
                # create a symbol for the course if doesnt exist
                if new_course_name not in courses_dict:
                    courses_dict[new_course_name] = Symbol(new_course_name)
        prereqs_dict[name] = eval(prerequisites_string, courses_dict)

# %%
# check results
prereqs_dict
# Out:
# {'ANTH214': CULT201,
#  'ARA302': ARA301,
#  'ARA303': ARA301,
#  'ARA304': ARA303,
#  'ARA502': ARA501,
#  'ARA503': ARA502,
#  'ARA504': ARA503,
#  'BIO301': NS202,
#  'BIO303': NS202,
#  'BIO304': NS202,
#  'BIO305': NS202,
#  'BIO306': NS202,
#  'BIO308': NS202,
#  'CIP102': CIP101 | TDP101,
#  'CIP201': CIP102 | TDP102,
#  'CIP202': CIP201 | TDP201,
#  'CIP301': CIP202 | TDP202,
#  'CIP302': CIP301,
#  'CS202': CS201,
#  'CS204': CS201,
#  'CS301': CS202 & MATH204,
#  'CS305': CS202,
#  'CS306': CS202,
#  'CS307': CS202,
#  'CS308': CS202,
#  'CS401': CS303,
#  'CS402': CS202 & CS305,
#  'CS403': CS307,
#  'CS404': CS201,
#  'CS405': CS202,
#  'CS406': CS301,
#  'CS407': CS302,
#  'CS408': CS307,
#  'CS409': CS201,
#  'CULT212': SPS101 & SPS102,
#  'CULT401': CULT201,
#  'ECON301': ECON204 & MATH306,
#  'ECON310': ECON204,
#  'ECON320': ECON204,
#  'ECON330': ECON204,
#  'ECON340': ECON202 & ECON204,
#  'ECON341': ECON201 & ECON204,
#  'ECON350': ECON202 & ECON204,
#  'ECON391': ECON202,
#  'ECON400': ECON202 & ECON204,
#  'ECON401': ECON301,
#  'ECON402': ECON202,
#  'ECON404': ECON204,
#  'ECON405': ECON201 & ECON204,
#  'ECON412': ECON301 & ECON330,
#  'ECON414': ECON202 & ECON301,
#  'ECON420': ECON202 & ECON204,
#  'ECON430': ECON202 & ECON204,
#  'ECON440': ECON340,
#  'ECON491': ECON204,
#  'ECON492': ECON202 & ECON204,
#  'ECON502': ECON501,
#  'ECON504': ECON503,
#  'ECON506': ECON505,
#  'EL202': ENS203,
#  'EL204': ENS203,
#  'EL302': EL202,
#  'EL303': EL202,
#  'EL304': EL202 & EL204,
#  'EL305': NS101,
#  'EL306': EL303 & ENS201,
#  'EL308': CS303,
#  'EL401': CS303 & EL302,
#  'EL402': EL401,
#  'EL405': EL303,
#  'EL407': EL204,
#  'ENG102': ENG101,
#  'ENS201': NS101 & (MATH101 | MATH102),
#  'ENS202': MATH101 & MATH102 & NS101 & NS102,
#  'ENS203': MATH101 & MATH102,
#  'ENS204': MATH101 & MATH102 & NS101,
#  'ENS205': MATH101 & MATH102 & NS102,
#  'ENS206': MATH101 & MATH102 & MATH201,
#  'ENS210': CS201 & MATH101,
#  'ENS211': MATH101 & MATH102,
#  'ENS301': NS101 & NS102,
#  'ENS491': PROJ302,
#  'GREK102': GREK101,
#  'HART323': HUM202 & SPS101,
#  'HIST191': TLL101,
#  'HIST192': HIST191 & TLL102,
#  'HIST316': HIST315,
#  'HIST345': SPS101 & SPS102,
#  'HIST363': SPS101 & SPS102,
#  'HIST502': HIST501,
#  'HIST511': HIST501 & HIST502,
#  'HIST512': HIST501 & HIST502,
#  'HIST601': TLL501 & TLL502,
#  'LIT212': CULT201,
#  'MAT202': ENS202,
#  'MATH202': MATH101 & MATH102,
#  'MATH203': MATH101 & MATH102,
#  'MATH305': MATH102,
#  'MATH306': MATH203,
#  'MATH317': MATH102 & MATH201,
#  'MATH322': MATH202,
#  'ME303': ENS206,
#  'ME307': MATH101 & MATH102 & NS101,
#  'ME403': ENS206,
#  'MS301': MATH201,
#  'MS302': MATH203,
#  'MS304': ENS208,
#  'MS305': MATH306,
#  'MS308': MS303,
#  'MS309': ENS205,
#  'MS401': MS304,
#  'MS403': MATH306,
#  'MS405': MATH203,
#  'MS408': MATH306,
#  'MS411': MS301,
#  'MS412': MS303,
#  'MS417': MS301,
#  'MS418': MS309,
#  'MS451': MATH306,
#  'NS202': MATH101 & MATH102 & NS102,
#  'NS203': MATH101 & MATH102 & NS101 & NS102,
#  'NS205': MATH101 & MATH102 & NS102,
#  'NS206': NS101,
#  'NS207': MATH101 & MATH102 & NS102,
#  'PERS502': PERS501,
#  'PERS504': PERS503,
#  'PHYS302': PHYS303,
#  'PHYS303': MATH101 & MATH102 & NS101,
#  'POLS301': SPS101 & SPS102,
#  'POLS302': POLS301,
#  'PROJ302': PROJ102,
#  'SOC201': SPS101 & SPS102,
#  'SPS102': SPS101,
#  'TE202': ENS201,
#  'TE302': ENS211,
#  'TE303': ENS211 & MATH203,
#  'TE304': TE303,
#  'TE401': ENS201,
#  'TE402': TE202,
#  'TE404': CS201,
#  'TE405': TE302,
#  'TE407': CS201,
#  'TE409': TE302,
#  'TE410': MATH201 & MATH203,
#  'TE412': TE304,
#  'TLL101': HIST191,
#  'TLL102': HIST192 & TLL101,
#  'TLL302': TLL301,
#  'TLL502': TLL501,
#  'VA202': VA201,
#  'VA204': VA203,
#  'VA301': VA201 & VA202 & VA203 & VA204,
#  'VA302': VA201 & VA202 & VA203 & VA204,
#  'VA321': VA201 & VA202 & VA203 & VA204,
#  'VA322': VA201 & VA202 & VA203 & VA204,
#  'VA323': VA201 & VA202 & VA203 & VA204,
#  'VA324': VA201 & VA202 & VA203 & VA204,
#  'VA331': VA201 & VA202 & VA203 & VA204,
#  'VA332': VA201 & VA202 & VA203 & VA204,
#  'VA334': VA201 & VA202 & VA203 & VA204,
#  'VA336': VA335,
#  'VA401': VA201 & VA202 & VA203 & VA204,
#  'VA402': VA201 & VA202 & VA203 & VA204,
#  'VA431': VA201 & VA202 & VA203 & VA204}

# %%
def is_it_cyclic(expr, search, hist=set()):
    ret = False
    if search in hist:
        return True
    
    
    # get sub-prerequisites for every course in the prerequisites
    for sub_course_symbol in expr.atoms():
        hist.add(sub_course_symbol)
        if isinstance(sub_course_symbol, Symbol):
            if search is sub_course_symbol:
                return True
            else:
                if sub_course_symbol.name in prereqs_dict:
                    ret = ret or is_it_cyclic(prereqs_dict[sub_course_symbol.name], sub_course_symbol)
    return ret

# %%
is_it_cyclic(prereqs_dict["HIST192"], courses_dict["HIST192"])
# Out:
# True

# %%
# returns set of of (course >> prerequisites) for all needed prerequisites for a given course 
# "set of prerequisite expressions of all courses a given course depends on in any way"
def get_all_prereqs(prerequisites, course=None, ret=set()):
    if not prerequisites:
        return ret
    
    if course:
        ret.add(course >> prerequisites)
    
    # get sub-prerequisites for every course in the prerequisites
    for sub_course_symbol in prerequisites.atoms():
        if isinstance(sub_course_symbol, Symbol) and sub_course_symbol.name in prereqs_dict:
            get_all_prereqs(prereqs_dict[sub_course_symbol.name], sub_course_symbol, ret)
    return ret

# %%
# test recursion with a 2 level deep example
get_all_prereqs(prereqs_dict["HIST192"], courses_dict["HIST192"])
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-39-301f6ba078ed> in <module>
#       1 # test recursion with a 2 level deep example
# ----> 2 get_all_prereqs(prereqs_dict["HIST192"], courses_dict["HIST192"])
#
# <ipython-input-38-1b870ef3dea1> in get_all_prereqs(prerequisites, course, ret)
#      11     for sub_course_symbol in prerequisites.atoms():
#      12         if isinstance(sub_course_symbol, Symbol) and sub_course_symbol.name in prereqs_dict:
# ---> 13             get_all_prereqs(prereqs_dict[sub_course_symbol.name], sub_course_symbol, ret)
#      14     return ret
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-38-1b870ef3dea1> in get_all_prereqs(prerequisites, course, ret)
#      11     for sub_course_symbol in prerequisites.atoms():
#      12         if isinstance(sub_course_symbol, Symbol) and sub_course_symbol.name in prereqs_dict:
# ---> 13             get_all_prereqs(prereqs_dict[sub_course_symbol.name], sub_course_symbol, ret)
#      14     return ret
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
# checks if a given expression is satisfiable with given assumptions
# givens should be a set of SymPy boolean expressions
def satisfiable_with_givens(expr, givens):
    return satisfiable(And(expr, *givens));

# %%
# checks if an arbitrary prerequisite expression (eg. "course & course & course") implies another
# true if a >> b
def prereq_implies_prereq(a, b):
    # a does not imply b if it is possible to have a=true b=false
    # check if (a&!b) is satisfiable
    # if it is satisfiable, implies is false. if it is not satisfiable, implies is true.
    res = satisfiable_with_givens(a&~b, get_all_prereqs(a) | get_all_prereqs(b))
    
    return not bool(res)

# %%
def a_is_redundant(func, a, b):
    if func is Or:
        return prereq_implies_prereq(a, b)
    elif func is And:
        return prereq_implies_prereq(b, a)

# %%
# returns A simplified prerequisite expression
def simplify_prereqs(course_prerequisites, verbose=True):
    if not isinstance(course_prerequisites, BooleanFunction):
        return course_prerequisites;

    parts = course_prerequisites.args

    # simplify all components of this prereq string before simplifying the whole thing
    parts = [simplify_prereqs(component, verbose) for component in parts]
    if verbose:
        print("analysing:", course_prerequisites.args, [(p, type(p)) for p in parts])
    
    
    for i in range(len(parts)):
        A = parts[i]
        B = course_prerequisites.func(*parts[0:i], *parts[i+1:len(parts)])
        if verbose:
            print(course_prerequisites.func, A, ",", B)
        
        
        # check if A is needed for this prerequisite
        p = a_is_redundant(course_prerequisites.func, A, B)
        
        # if A is redundant
        if p: 
            if verbose:
                print(strike("("+str(A)+")"), sep="", end=" ")
            # remove A from the prereq string by making it the identity for this operation
            parts[i] = course_prerequisites.func.identity
    return course_prerequisites.func(*parts)

# %%
def check(course):
    print("checking", course+":\ncurrent prereq is:")
    print(prereqs_dict[course])
    print("processed prereq is:")
    print("\n"+str(simplify_prereqs(prereqs_dict[course])))
    print("\n")

check("CS406")
check("ECON400")
# Out:
# checking CS406:
# current prereq is:
# CS301
# processed prereq is:
#
# CS301
#
#
# checking ECON400:
# current prereq is:
# ECON202 & ECON204
# processed prereq is:
# analysing: (ECON202, ECON204) [(ECON202, <class 'sympy.core.symbol.Symbol'>), (ECON204, <class 'sympy.core.symbol.Symbol'>)]
# And ECON202 , ECON204
# And ECON204 , ECON202
#
# ECON202 & ECON204

# %%
# use our methods to analyze all courses that have prerequisites, then save the simplified prerequisites
changes = {}
new_prereqs_dict = {}
c = 0
chrono2 = time.perf_counter()

for (full_name, name) in fullnames_dict.items():
    print("doing", name)
    if name in prereqs_dict:
        prereqs = prereqs_dict[name]
        new_prereqs = simplify_prereqs(prereqs, False)
        new_prereqs_dict[full_name] = new_prereqs
        if not prereqs.equals(new_prereqs):
            changes[full_name] = {"old": str(prereqs), "new": str(new_prereqs)}
        c+=1
        
    else:
        new_prereqs_dict[full_name] = ""

end = time.perf_counter()
chrono1 = end - chrono1
chrono2 = end - chrono2
print("Analysis complete,", c, "prerequisite expressions in", chrono2, "seconds.")
print("Average of", chrono2/c, "seconds per expression.")
print("Totals:")
print("\tcourses:", len(new_prereqs_dict))
print("\tchanges:", len(changes))
print("\ttime:", chrono1, "seconds")


# save outputs
with open('updatedValues.json', 'w') as fp:
    json.dump({n: str(p) for (n, p) in new_prereqs_dict.items()}, fp)

with open('changelist.json', 'w') as fp:
    json.dump(changes, fp)
# Out:
# doing ANTH214
# doing ANTH255
# doing ARA301
# doing ARA302
# doing ARA303
# doing ARA304
# doing ARA501
# doing ARA502
# doing ARA503
# doing ARA504
# doing BIO301
# doing BIO301L
# doing BIO303
# doing BIO303L
# doing BIO304
# doing BIO305
# doing BIO306
# doing BIO306L
# doing BIO308
# doing BIO308L
# doing BIO310
# doing BIO332
# doing BIO332R
# doing BIO401
# doing BIO403
# doing BIO404
# doing BIO405
# doing BIO406
# doing BIO407
# doing BIO409
# doing BIO410
# doing BIO432
# doing BIO432L
# doing BIO480
# doing BIO501
# doing BIO504
# doing BIO504L
# doing BIO511
# doing BIO512
# doing BIO532
# doing BIO541
# doing BIO543
# doing BIO543L
# doing BIO551
# doing BIO552
# doing BIO580
# doing BIO581
# doing BIO590
# doing BIO601
# doing BIO604
# doing BIO610
# doing BIO631
# doing BIO641
# doing BIO642
# doing BIO643
# doing BIO643L
# doing BIO680
# doing BIO681
# doing BIO790
# doing CHEM301
# doing CHEM301L
# doing CHEM302
# doing CHEM302L
# doing CIP101
# doing CIP102
# doing CIP201
# doing CIP202
# doing CIP301
# doing CIP302
# doing CONF601
# doing CONF602
# doing CONF604
# doing CONF608
# doing CONF611
# doing CONF612
# doing CONF623
# doing CONF624
# doing CONF631
# doing CONF636
# doing CONF641
# doing CONF690
# doing CONF693
# doing CONF697
# doing CONF699
# doing CS201
# doing CS201L
# doing CS201R
# doing CS202
# doing CS202R
# doing CS204
# doing CS204L
# doing CS301
# doing CS302
# doing CS302R
# doing CS303
# doing CS303L
# doing CS303R
# doing CS305
# doing CS306
# doing CS306R
# doing CS307
# doing CS307R
# doing CS308
# doing CS308L
# doing CS401
# doing CS402
# doing CS403
# doing CS404
# doing CS405
# doing CS405L
# doing CS406
# doing CS407
# doing CS407R
# doing CS408
# doing CS409
# doing CS480
# doing CS501
# doing CS503
# doing CS505
# doing CS507
# doing CS512
# doing CS513
# doing CS513R
# doing CS515
# doing CS518
# doing CS522
# doing CS523
# doing CS525
# doing CS531
# doing CS532
# doing CS533
# doing CS533L
# doing CS534
# doing CS538
# doing CS541
# doing CS543
# doing CS545
# doing CS551
# doing CS552
# doing CS580
# doing CS581
# doing CS601
# doing CS611
# doing CS680
# doing CS681
# doing CULT201
# doing CULT212
# doing CULT222
# doing CULT224
# doing CULT225
# doing CULT231
# doing CULT232
# doing CULT242
# doing CULT250
# doing CULT251
# doing CULT291
# doing CULT322
# doing CULT323
# doing CULT326
# doing CULT331
# doing CULT342
# doing CULT344
# doing CULT362
# doing CULT399
# doing CULT401
# doing CULT423
# doing CULT433
# doing CULT443
# doing CULT444
# doing CULT643
# doing ECON201
# doing ECON201R
# doing ECON202
# doing ECON202R
# doing ECON204
# doing ECON204R
# doing ECON301
# doing ECON301R
# doing ECON310
# doing ECON320
# doing ECON330
# doing ECON330R
# doing ECON340
# doing ECON341
# doing ECON350
# doing ECON391
# doing ECON391R
# doing ECON399
# doing ECON400
# doing ECON401
# doing ECON402
# doing ECON403
# doing ECON404
# doing ECON405
# doing ECON405R
# doing ECON412
# doing ECON414
# doing ECON420
# doing ECON430
# doing ECON440
# doing ECON491
# doing ECON492
# doing ECON501
# doing ECON501R
# doing ECON502
# doing ECON503
# doing ECON503R
# doing ECON504
# doing ECON505
# doing ECON505R
# doing ECON506
# doing ECON601
# doing ECON602
# doing ECON603
# doing ECON604
# doing ECON605
# doing ECON606
# doing ECON607
# doing ECON608
# doing ECON609
# doing ECON610
# doing ECON611
# doing ECON697
# doing ECON699
# doing EE520
# doing EE520R
# doing EE521
# doing EE522
# doing EE523
# doing EE524
# doing EE524L
# doing EE525
# doing EE526
# doing EE528
# doing EE528R
# doing EE530
# doing EE531
# doing EE532
# doing EE533
# doing EE534
# doing EE535
# doing EE536
# doing EE537
# doing EE539
# doing EE550
# doing EE551
# doing EE552
# doing EE553
# doing EE554
# doing EE555
# doing EE556
# doing EE557
# doing EE560
# doing EE561
# doing EE562
# doing EE563
# doing EE565
# doing EE566
# doing EE580
# doing EE581
# doing EE581L
# doing EE582
# doing EE583
# doing EE584
# doing EE585
# doing EE620
# doing EE622
# doing EE623
# doing EE624
# doing EE626
# doing EE630
# doing EE631
# doing EE632
# doing EE633
# doing EE634
# doing EE635
# doing EE636
# doing EE637
# doing EE638
# doing EE651
# doing EE652
# doing EE653
# doing EE654
# doing EE661
# doing EE662
# doing EE665
# doing EE680
# doing EE681
# doing EE682
# doing EE683
# doing EE684
# doing EE685
# doing EECS590
# doing EECS592
# doing EECS790
# doing EL202
# doing EL202L
# doing EL202R
# doing EL204
# doing EL204R
# doing EL302
# doing EL302L
# doing EL302R
# doing EL303
# doing EL303R
# doing EL304
# doing EL304R
# doing EL305
# doing EL306
# doing EL306R
# doing EL308
# doing EL308L
# doing EL308R
# doing EL401
# doing EL401L
# doing EL401R
# doing EL402
# doing EL402R
# doing EL404
# doing EL405
# doing EL405L
# doing EL407
# doing EL407R
# doing EL480
# doing ENG001
# doing ENG002
# doing ENG003
# doing ENG101
# doing ENG102
# doing ENS201
# doing ENS201R
# doing ENS202
# doing ENS202R
# doing ENS203
# doing ENS203L
# doing ENS203R
# doing ENS204
# doing ENS204R
# doing ENS205
# doing ENS205R
# doing ENS206
# doing ENS206L
# doing ENS206R
# doing ENS208
# doing ENS208R
# doing ENS210
# doing ENS210L
# doing ENS211
# doing ENS211R
# doing ENS301
# doing ENS491
# doing ENS491R
# doing ENS492
# doing ENS502
# doing ENS596
# doing FRE101
# doing FRE102
# doing FRE201
# doing FRE202
# doing FRE301
# doing FRE302
# doing GER101
# doing GER102
# doing GER201
# doing GER202
# doing GER301
# doing GER302
# doing GER401
# doing GER402
# doing GREK101
# doing GREK102
# doing GSM5001
# doing GSM5003
# doing GSM5004
# doing GSM501
# doing GSM5013
# doing GSM502
# doing GSM503
# doing GSM504
# doing GSM505
# doing GSM509
# doing GSM510
# doing GSM5108
# doing GSM511
# doing GSM512
# doing GSM513
# doing GSM514
# doing GSM5203
# doing GSM5207
# doing GSM5209
# doing GSM5211
# doing GSM5213
# doing GSM523
# doing GSM525
# doing GSM527
# doing GSM528
# doing GSM529
# doing GSM530
# doing GSM5309
# doing GSM531
# doing GSM5311
# doing GSM5313
# doing GSM532
# doing GSM541
# doing GSM543
# doing GSM545
# doing GSM547
# doing GSM549
# doing GSM5501
# doing GSM5502
# doing GSM5503
# doing GSM5505
# doing GSM551
# doing GSM553
# doing GSM581
# doing GSM582
# doing GSM583
# doing GSM585
# doing GSM587
# doing GSM590
# doing GSM591
# doing GSM592
# doing GSM593
# doing GSM594
# doing GSM595
# doing GSM596
# doing GSM599
# doing GSM601
# doing GSM602
# doing GSM604
# doing GSM605
# doing GSM606
# doing GSM608
# doing GSM609
# doing GSM610
# doing GSM612
# doing GSM613
# doing GSM617
# doing GSM618
# doing GSM619
# doing GSM621
# doing GSM622
# doing GSM629
# doing GSM655
# doing GSM656
# doing GSM671
# doing GSM681
# doing GSM691
# doing GSM700
# doing HART213
# doing HART292
# doing HART311
# doing HART323
# doing HART392
# doing HART411
# doing HART413
# doing HART430
# doing HART432
# doing HART523
# doing HART624
# doing HIST191
# doing HIST192
# doing HIST221
# doing HIST223
# doing HIST227
# doing HIST242
# doing HIST285
# doing HIST311
# doing HIST315
# doing HIST316
# doing HIST323
# doing HIST331
# doing HIST341
# doing HIST345
# doing HIST363
# doing HIST397
# doing HIST436
# doing HIST450
# doing HIST455
# doing HIST461
# doing HIST462
# doing HIST489
# doing HIST492
# doing HIST494
# doing HIST497
# doing HIST500
# doing HIST501
# doing HIST502
# doing HIST511
# doing HIST512
# doing HIST513
# doing HIST514
# doing HIST519
# doing HIST521
# doing HIST525
# doing HIST531
# doing HIST547
# doing HIST549
# doing HIST555
# doing HIST556
# doing HIST561
# doing HIST572
# doing HIST581
# doing HIST591
# doing HIST592
# doing HIST596
# doing HIST599
# doing HIST600
# doing HIST601
# doing HIST602
# doing HIST609
# doing HIST611
# doing HIST613
# doing HIST621
# doing HIST622
# doing HIST623
# doing HIST631
# doing HIST632
# doing HIST633
# doing HIST634
# doing HIST647
# doing HIST650
# doing HIST652
# doing HIST671
# doing HIST682
# doing HIST689
# doing HIST692
# doing HIST694
# doing HIST695
# doing HIST696
# doing HIST699
# doing HIST702
# doing HIST712
# doing HIST714
# doing HIST715
# doing HIST742
# doing HIST751
# doing HIST762
# doing HIST771
# doing HIST781
# doing HIST791
# doing HIST799
# doing HUM201
# doing HUM201D
# doing HUM202
# doing HUM202D
# doing IE501
# doing IE503
# doing IE512
# doing IE514
# doing IE518
# doing IE519
# doing IE522
# doing IE524
# doing IE550
# doing IE551
# doing IE552
# doing IE553
# doing IE554
# doing IE556
# doing IE563
# doing IE563L
# doing IE564
# doing IE564L
# doing IE565
# doing IE567
# doing IE580
# doing IE581
# doing IE590
# doing IE592
# doing IE601
# doing IE605
# doing IE606
# doing IE609
# doing IE632
# doing IE638
# doing IE680
# doing IE681
# doing IE790
# doing IR201
# doing IR291
# doing IR292
# doing IR310
# doing IR341
# doing IR392
# doing IR394
# doing IT511
# doing IT512
# doing IT520
# doing IT521
# doing IT522
# doing IT523
# doing IT524
# doing IT525
# doing IT526
# doing IT531
# doing IT532
# doing IT533
# doing IT534
# doing IT553
# doing IT560
# doing IT592
# doing LIT212
# doing LIT324
# doing LIT334
# doing LIT343
# doing LIT354
# doing LIT394
# doing LIT431
# doing LIT452
# doing LIT624
# doing MAN350
# doing MAN370
# doing MAN380
# doing MAN390
# doing MAN410
# doing MAT202
# doing MAT202L
# doing MAT204
# doing MAT204R
# doing MAT301
# doing MAT302
# doing MAT302L
# doing MAT304
# doing MAT305
# doing MAT306
# doing MAT307
# doing MAT307R
# doing MAT308
# doing MAT310
# doing MAT312
# doing MAT312L
# doing MAT401
# doing MAT402
# doing MAT403
# doing MAT404
# doing MAT404D
# doing MAT406
# doing MAT408
# doing MAT416
# doing MAT480
# doing MAT501
# doing MAT502
# doing MAT503
# doing MAT504
# doing MAT505
# doing MAT506
# doing MAT507
# doing MAT508
# doing MAT509
# doing MAT509L
# doing MAT510
# doing MAT511
# doing MAT511L
# doing MAT514
# doing MAT514D
# doing MAT516
# doing MAT520
# doing MAT521
# doing MAT522
# doing MAT551
# doing MAT552
# doing MAT560
# doing MAT563
# doing MAT570
# doing MAT571
# doing MAT571L
# doing MAT580
# doing MAT581
# doing MAT590
# doing MAT591
# doing MAT592
# doing MAT601
# doing MAT602
# doing MAT611
# doing MAT620
# doing MAT621
# doing MAT622
# doing MAT630
# doing MAT632
# doing MAT672
# doing MAT680
# doing MAT681
# doing MAT790
# doing MATH101
# doing MATH101R
# doing MATH102
# doing MATH102R
# doing MATH201
# doing MATH201R
# doing MATH202
# doing MATH202R
# doing MATH203
# doing MATH203R
# doing MATH204
# doing MATH204R
# doing MATH301
# doing MATH302
# doing MATH305
# doing MATH306
# doing MATH306R
# doing MATH311
# doing MATH317
# doing MATH322
# doing MATH405
# doing MATH414
# doing MATH417
# doing MATH480
# doing MATH501
# doing MATH502
# doing MATH503
# doing MATH504
# doing MATH505
# doing MATH511
# doing MATH512
# doing MATH514
# doing MATH515
# doing MATH517
# doing MATH521
# doing MATH522
# doing MATH531
# doing MATH532
# doing MATH533
# doing MATH541
# doing MATH542
# doing MATH544
# doing MATH551
# doing MATH552
# doing MATH590
# doing MATH601
# doing MATH602
# doing MATH612
# doing MATH615
# doing MATH616
# doing MATH617
# doing MATH618
# doing MATH621
# doing MATH622
# doing MATH631
# doing MATH632
# doing MATH636
# doing MATH637
# doing MATH638
# doing MATH790
# doing ME301
# doing ME301R
# doing ME302
# doing ME302L
# doing ME302R
# doing ME303
# doing ME303R
# doing ME304
# doing ME304R
# doing ME305
# doing ME305R
# doing ME307
# doing ME307R
# doing ME308
# doing ME308R
# doing ME309
# doing ME309R
# doing ME403
# doing ME403R
# doing ME404
# doing ME404R
# doing ME405
# doing ME405R
# doing ME406
# doing ME406R
# doing ME407
# doing ME407L
# doing ME410
# doing ME412
# doing ME412R
# doing ME480
# doing MS301
# doing MS301R
# doing MS302
# doing MS302R
# doing MS303
# doing MS303R
# doing MS304
# doing MS305
# doing MS305R
# doing MS306
# doing MS307
# doing MS308
# doing MS309
# doing MS309R
# doing MS401
# doing MS402
# doing MS402L
# doing MS403
# doing MS405
# doing MS407
# doing MS408
# doing MS409
# doing MS411
# doing MS412
# doing MS413
# doing MS414
# doing MS417
# doing MS418
# doing MS418L
# doing MS419
# doing MS420
# doing MS451
# doing MS480
# doing NS101
# doing NS101L
# doing NS101R
# doing NS102
# doing NS102L
# doing NS102R
# doing NS202
# doing NS202L
# doing NS203
# doing NS203L
# doing NS203R
# doing NS205
# doing NS206
# doing NS207
# doing NS207L
# doing NS207R
# doing NS501
# doing NS502
# doing OPIM302
# doing PERS501
# doing PERS502
# doing PERS503
# doing PERS504
# doing PHIL433
# doing PHYS302
# doing PHYS302R
# doing PHYS303
# doing PHYS304
# doing PHYS412
# doing POLS222
# doing POLS250
# doing POLS254
# doing POLS271
# doing POLS301
# doing POLS302
# doing POLS303
# doing POLS304
# doing POLS351
# doing POLS352
# doing POLS364
# doing POLS372
# doing POLS383
# doing POLS384
# doing POLS392
# doing POLS393
# doing POLS421
# doing POLS441
# doing POLS453
# doing POLS455
# doing POLS473
# doing POLS491
# doing POLS492
# doing POLS495
# doing POLS501
# doing POLS503
# doing POLS512
# doing POLS521
# doing POLS583
# doing POLS584
# doing POLS593
# doing POLS594
# doing POLS595
# doing POLS610
# doing POLS700A
# doing POLS700B
# doing POLS790A
# doing POLS790B
# doing POLS799
# doing PROJ102
# doing PROJ300
# doing PROJ302
# doing SOC201
# doing SOC313
# doing SOC321
# doing SOC444
# doing SPA101
# doing SPA102
# doing SPA201
# doing SPA202
# doing SPA301
# doing SPA302
# doing SPA401
# doing SPA402
# doing SPS101
# doing SPS101D
# doing SPS102
# doing SPS102D
# doing SPS211
# doing SPS303
# doing SPS303D
# doing SPS311
# doing SPS311D
# doing SPS312
# doing SPS399
# doing SPS442
# doing TE202
# doing TE202R
# doing TE302
# doing TE302R
# doing TE303
# doing TE303R
# doing TE304
# doing TE304L
# doing TE304R
# doing TE401
# doing TE402
# doing TE404
# doing TE404R
# doing TE405
# doing TE407
# doing TE407L
# doing TE409
# doing TE409L
# doing TE410
# doing TE412
# doing TE480
# doing TLL001
# doing TLL101
# doing TLL102
# doing TLL301
# doing TLL302
# doing TLL501
# doing TLL502
# doing VA201
# doing VA202
# doing VA203
# doing VA204
# doing VA210
# doing VA212
# doing VA215
# doing VA301
# doing VA302
# doing VA321
# doing VA322
# doing VA323
# doing VA324
# doing VA329
# doing VA331
# doing VA332
# doing VA333
# doing VA334
# doing VA335
# doing VA336
# doing VA344
# doing VA399
# doing VA401
# doing VA402
# doing VA431
# doing VA432
# doing VA433
# doing VA434
# doing VA440
# doing VA441
# doing VA442
# doing VA501
# doing VA502
# doing VA503
# doing VA504
# doing VA510
# doing VA511
# doing VA512
# doing VA513
# doing VA514
# doing VA515
# doing VA520
# doing VA521
# doing VA522
# doing VA523
# doing VA524
# doing VA525
# doing VA526
# doing VA527
# doing VA528
# doing VA530
# doing VA531
# doing VA532
# doing VA533
# doing VA540
# doing VA541
# doing VA542
# doing VA543
# doing VA544
# doing VA590
# doing VA599
# Analysis complete, 162 prerequisite expressions in 0.8045804000003045 seconds.
# Average of 0.004966545679014225 seconds per expression.
# Totals:
# 	courses: 992
# 	changes: 21
# 	time: 1.1465924000003724 seconds
